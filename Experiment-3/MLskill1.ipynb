# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns
print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.2
# NumPy          : 2.0.2
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
import pandas as pd
import seaborn as sns

# %%
import pandas as pd

# List the file paths
file_paths = [
    '/content/gender_submission.csv',
    '/content/train.csv',
    '/content/test.csv'
]

# Read and combine them into a single DataFrame
df = pd.concat([pd.read_csv(f) for f in file_paths], ignore_index=True)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass Name  Sex  Age  SibSp  Parch Ticket  Fare  \
# 0          892       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 1          893       1.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 2          894       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 3          895       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 4          896       1.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
#
#   Cabin Embarked
# 0   NaN      NaN
# 1   NaN      NaN
# 2   NaN      NaN
# 3   NaN      NaN
# 4   NaN      NaN

# %%
df.tail(5)
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1722         1305       NaN     3.0            Spector, Mr. Woolf    male
# 1723         1306       NaN     1.0  Oliva y Ocana, Dona. Fermina  female
# 1724         1307       NaN     3.0  Saether, Mr. Simon Sivertsen    male
# 1725         1308       NaN     3.0           Ware, Mr. Frederick    male
# 1726         1309       NaN     3.0      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 1722   NaN    0.0    0.0           A.5. 3236    8.0500   NaN        S
# 1723  39.0    0.0    0.0            PC 17758  108.9000  C105        C
# 1724  38.5    0.0    0.0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1725   NaN    0.0    0.0              359309    8.0500   NaN        S
# 1726   NaN    1.0    1.0                2668   22.3583   NaN        C

# %%
df.shape
# Out:
# (1727, 12)

# %%
df['PassengerId']
# Out:
# 0        892
# 1        893
# 2        894
# 3        895
# 4        896
#         ...
# 1722    1305
# 1723    1306
# 1724    1307
# 1725    1308
# 1726    1309
# Name: PassengerId, Length: 1727, dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass         float64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    6
# object     5
# int64      1
# Name: count, dtype: int64

# %%
missing_data = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})

missing_data
# Out:
#              Missing Values  Percentage
# PassengerId               0    0.000000
# Survived                418   24.203822
# Pclass                  418   24.203822
# Name                    418   24.203822
# Sex                     418   24.203822
# Age                     681   39.432542
# SibSp                   418   24.203822
# Parch                   418   24.203822
# Ticket                  418   24.203822
# Fare                    419   24.261726
# Cabin                  1432   82.918356
# Embarked                420   24.319629

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
# cbar=False hides the color bar; yticklabels=False hides row numbers for cleaner v
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("missing")
plt.show()

# %%
duplicate_rows = df[df.duplicated()]
print(f"Total duplicate rows detected: {len(duplicate_rows)}")
print(duplicate_rows)
print("-" * 40)
# Out:
# Total duplicate rows detected: 0
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
# ----------------------------------------

# %%
#display rows where null values are present if any
df[df['Parch'].isnull()]
# Out:
#      PassengerId  Survived  Pclass Name  Sex  Age  SibSp  Parch Ticket  Fare  \
# 0            892       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 1            893       1.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 2            894       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 3            895       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 4            896       1.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# ..           ...       ...     ...  ...  ...  ...    ...    ...    ...   ...
# 413         1305       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 414         1306       1.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 415         1307       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 416         1308       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 417         1309       0.0     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
#
#     Cabin Embarked
# 0     NaN      NaN
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN
# ..    ...      ...
# 413   NaN      NaN
# 414   NaN      NaN
# 415   NaN      NaN
# 416   NaN      NaN
# 417   NaN      NaN
#
# [418 rows x 12 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1727, 12)

# %%
df.describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1727.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    762.828025     0.377387     2.294882    29.881138     0.498854
# std     385.032264     0.484918     0.837836    14.413493     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     432.500000     0.000000     2.000000    21.000000     0.000000
# 50%     864.000000     0.000000     3.000000    28.000000     0.000000
# 75%    1093.500000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3.0    709
# 1.0    323
# 2.0    277
# Name: count, dtype: int64

# %%
(df["SibSp"].value_counts(normalize=True) * 100).round(2)
# Out:
# SibSp
# 0.0    68.07
# 1.0    24.37
# 2.0     3.21
# 4.0     1.68
# 3.0     1.53
# 8.0     0.69
# 5.0     0.46
# Name: proportion, dtype: float64

# %%
print(df.columns.tolist())
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
